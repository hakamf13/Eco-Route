# %%
import csv
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tabulate import tabulate
import warnings

# %matplotlib inline
import matplotlib.pyplot as plt  # Matlab-style plotting
import seaborn as sns
color = sns.color_palette()
sns.set_style('darkgrid')
import warnings
def ignore_warn(*args, **kwargs):
    pass
warnings.warn = ignore_warn #ignore annoying warning (from sklearn and seaborn)

from scipy import stats
from scipy.stats import norm, skew #for some statistics

pd.set_option('display.float_format', lambda x: '{:.3f}'.format(x)) #Limiting floats output to 3 decimal points

# %%
def read_car_data():
    car_data = pd.read_csv('car_data_dummy.csv', delimiter=';')
    return car_data

# %%
car_data = read_car_data()
car_data.head()
# Out:
#    YEAR         CAR TYPE  VEHICLE CLASS  ENGINE SIZE (L)  CYLINDERS  \
# 0  2010  TOYOTA AVANZA E  STATION WAGON            1.300          4
# 1  2010  TOYOTA AVANZA G  STATION WAGON            1.500          4
# 2  2010  TOYOTA AVANZA G  STATION WAGON            1.500          4
# 3  2013  TOYOTA AVANZA E  STATION WAGON            1.300          4
# 4  2013  TOYOTA AVANZA E  STATION WAGON            1.300          4
#
#   TRANSMISSION FUEL TYPE  FUEL CONSUMPTION CITY  FUEL CONSUMPTION HWY  \
# 0           MT    BENSIN                  8.700                 6.400
# 1           MT    BENSIN                  9.300                 6.700
# 2           AT    BENSIN                 10.000                 7.400
# 3           MT    BENSIN                  8.600                 6.200
# 4           AT    BENSIN                  9.000                 6.400
#
#    COMB (L/100 km)  COMB (mpg)  CO2 EMISSIONS
# 0            8.700      32.200            193
# 1            9.000      31.400            208
# 2           10.000      23.500            233
# 3            8.200      34.600            192
# 4            8.700      32.200            199

# %%
car_data.tail()
# Out:
#     YEAR               CAR TYPE  VEHICLE CLASS  ENGINE SIZE (L)  CYLINDERS  \
# 26  2020         TOYOTA CALYA E  STATION WAGON            1.200          4
# 27  2020         TOYOTA CALYA G  STATION WAGON            1.200          4
# 28  2020         TOYOTA CALYA G  STATION WAGON            1.200          4
# 29  2020         TOYOTA CALYA G  STATION WAGON            1.200          4
# 30  2020  TOYOTA CALYA G SPORTY  STATION WAGON            1.200          4
#
#    TRANSMISSION FUEL TYPE  FUEL CONSUMPTION CITY  FUEL CONSUMPTION HWY  \
# 26           MT    BENSIN                  5.000                 4.200
# 27           MT    BENSIN                  5.100                 4.300
# 28           AT    BENSIN                  5.200                 4.300
# 29           MT    BENSIN                  5.000                 4.200
# 30           AT    BENSIN                  5.300                 4.400
#
#     COMB (L/100 km)  COMB (mpg)  CO2 EMISSIONS
# 26            5.000      47.600            100
# 27            5.100      47.700            101
# 28            5.200      45.200            105
# 29            5.000      47.600            100
# 30            5.300      45.300            106

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   YEAR                   31 non-null     int64
#  1   CAR TYPE               31 non-null     object
#  2   VEHICLE CLASS          31 non-null     object
#  3   ENGINE SIZE (L)        31 non-null     float64
#  4   CYLINDERS              31 non-null     int64
#  5   TRANSMISSION           31 non-null     object
#  6   FUEL TYPE              31 non-null     object
#  7   FUEL CONSUMPTION CITY  31 non-null     float64
#  8   FUEL CONSUMPTION HWY   31 non-null     float64
#  9   COMB (L/100 km)        31 non-null     float64
#  10  COMB (mpg)             31 non-null     float64
#  11  CO2 EMISSIONS          31 non-null     int64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 3.0+ KB

# %%
car_data.describe()
# Out:
#           YEAR  ENGINE SIZE (L)  CYLINDERS  FUEL CONSUMPTION CITY  \
# count   31.000           31.000     31.000                 31.000
# mean  2017.194            1.255      3.742                  6.605
# std      4.094            0.175      0.445                  1.982
# min   2010.000            1.000      3.000                  4.600
# 25%   2013.000            1.200      3.500                  5.000
# 50%   2020.000            1.200      4.000                  5.200
# 75%   2020.000            1.400      4.000                  8.750
# max   2022.000            1.500      4.000                 10.000
#
#        FUEL CONSUMPTION HWY  COMB (L/100 km)  COMB (mpg)  CO2 EMISSIONS
# count                31.000           31.000      31.000         31.000
# mean                  5.186            6.500      41.588        142.323
# std                   1.198            2.015       9.675         51.158
# min                   4.000            4.400      23.500         88.000
# 25%                   4.165            5.000      32.200        100.500
# 50%                   4.300            5.200      45.300        106.000
# 75%                   6.400            8.700      47.700        196.000
# max                   7.400           10.000      53.500        233.000

# %%
car_data.columns
# Out:
# Index(['YEAR', 'CAR TYPE', 'VEHICLE CLASS', 'ENGINE SIZE (L)', 'CYLINDERS',
#        'TRANSMISSION', 'FUEL TYPE', 'FUEL CONSUMPTION CITY',
#        'FUEL CONSUMPTION HWY', 'COMB (L/100 km)', 'COMB (mpg)',
#        'CO2 EMISSIONS'],
#       dtype='object')

# %%
car_data.isna().sum()
# Out:
# YEAR                     0
# CAR TYPE                 0
# VEHICLE CLASS            0
# ENGINE SIZE (L)          0
# CYLINDERS                0
# TRANSMISSION             0
# FUEL TYPE                0
# FUEL CONSUMPTION CITY    0
# FUEL CONSUMPTION HWY     0
# COMB (L/100 km)          0
# COMB (mpg)               0
# CO2 EMISSIONS            0
# dtype: int64

# %%
fig, ax = plt.subplots()
ax.scatter(x = car_data['CYLINDERS'], y = car_data['CO2 EMISSIONS'])
plt.ylabel('CO2 EMISSIONS', fontsize=13)
plt.xlabel('CYLINDERS', fontsize=13)
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(x = car_data['FUEL CONSUMPTION CITY'], y = car_data['CO2 EMISSIONS'])
plt.ylabel('CO2 EMISSIONS', fontsize=13)
plt.xlabel('FUEL CONSUMPTION CITY', fontsize=13)
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(x = car_data['FUEL CONSUMPTION HWY'], y = car_data['CO2 EMISSIONS'])
plt.ylabel('CO2 EMISSIONS', fontsize=13)
plt.xlabel('FUEL CONSUMPTION HWY', fontsize=13)
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(x = car_data['COMB (L/100 km)'], y = car_data['CO2 EMISSIONS'])
plt.ylabel('CO2 EMISSIONS', fontsize=13)
plt.xlabel('COMB (L/100 km)', fontsize=13)
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(x = car_data['COMB (mpg)'], y = car_data['CO2 EMISSIONS'])
plt.ylabel('CO2 EMISSIONS', fontsize=13)
plt.xlabel('COMB (mpg)', fontsize=13)
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(x = car_data['YEAR'], y = car_data['CO2 EMISSIONS'])
plt.ylabel('CO2 EMISSIONS', fontsize=13)
plt.xlabel('YEAR', fontsize=13)
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(x = car_data['ENGINE SIZE (L)'], y = car_data['CO2 EMISSIONS'])
plt.ylabel('CO2 EMISSIONS', fontsize=13)
plt.xlabel('ENGINE SIZE (L)', fontsize=13)
plt.show()

# %%
sns.pairplot(car_data[['CAR TYPE', 'YEAR', 'VEHICLE CLASS', 'ENGINE SIZE (L)', 'CYLINDERS', 'TRANSMISSION', 'FUEL TYPE', 'FUEL CONSUMPTION CITY'
                , 'FUEL CONSUMPTION HWY', 'COMB (L/100 km)', 'COMB (mpg)', 'CO2 EMISSIONS']], diag_kind='kde')

# %%
#Correlation map to see how features are correlated with SalePrice
corrmat = car_data.corr()
plt.subplots(figsize=(12,9))
sns.heatmap(corrmat, vmax=0.9, square=True, annot=True)
# Out:
# <Axes: >

# %%
# Max limit input
max_limit_input = float(input("Set the maximum limit of carbon emissions per day (gram): "))
# Set the user car's detail
mileage = float(input("Enter your car mileage in km: "))
car_type = input("Enter your car type: ").upper()
car_year = int(input("Enter your car year: "))
fuel_type = input("Enter your car fuel type: ").upper()
car_transmission = input("Enter your car transmission: ").upper()

#usercar = pd.DataFrame()
usercar = car_data.loc[(car_data['CAR TYPE'] == car_type) & (car_data['YEAR'] == car_year) & (car_data['FUEL TYPE'] == fuel_type) & (car_data['TRANSMISSION'] == car_transmission)]
# Out:
# Set the maximum limit of carbon emissions per day (gram): 100
# Enter your car mileage in km: 1
# Enter your car type: toyota avanza e
# Enter your car year: 2010
# Enter your car fuel type: bensin
# Enter your car transmission: mt

# %%
lect = LabelEncoder()
car_data['CAR TYPE'] = lect.fit_transform(car_data['CAR TYPE'])
usercar['CAR TYPE'] = lect.transform(usercar['CAR TYPE'])

ley = LabelEncoder()
car_data['YEAR'] = ley.fit_transform(car_data['YEAR'])
usercar['YEAR'] = ley.transform(usercar['YEAR'])

levc = LabelEncoder()
car_data['VEHICLE CLASS'] = levc.fit_transform(car_data['VEHICLE CLASS'])
usercar['VEHICLE CLASS'] = levc.transform(usercar['VEHICLE CLASS'])

lees = LabelEncoder()
car_data['ENGINE SIZE (L)'] = levc.fit_transform(car_data['ENGINE SIZE (L)'])
usercar['ENGINE SIZE (L)'] = levc.transform(usercar['ENGINE SIZE (L)'])

lecs = LabelEncoder()
car_data['CYLINDERS'] = lecs.fit_transform(car_data['CYLINDERS'])
usercar['CYLINDERS'] = lecs.transform(usercar['CYLINDERS'])

letr = LabelEncoder()
car_data['TRANSMISSION'] = letr.fit_transform(car_data['TRANSMISSION'])
usercar['TRANSMISSION'] = letr.transform(usercar['TRANSMISSION'])

left = LabelEncoder()
car_data['FUEL TYPE'] = left.fit_transform(car_data['FUEL TYPE'])
usercar['FUEL TYPE'] = left.transform(usercar['FUEL TYPE'])

# %%
labels = np.array(car_data['CO2 EMISSIONS'])
car_data = car_data.drop('CO2 EMISSIONS', axis = 1)
real = np.array(usercar['CO2 EMISSIONS'])
usercar = usercar.drop('CO2 EMISSIONS', axis = 1)
datalist = list(car_data.columns)
car_data = np.array(car_data)

# %%
# Select relevant features for training the model
features = ['YEAR', 'CAR TYPE', 'VEHICLE CLASS', 'ENGINE SIZE (L)', 'CYLINDERS', 'TRANSMISSION', 'FUEL TYPE', 'FUEL CONSUMPTION CITY', 'FUEL CONSUMPTION HWY', 'COMB (mpg)', 'COMB (L/100 km)']
target = 'CO2 EMISSIONS'

# %%
train_data, test_data, train_target, test_target = train_test_split(
        car_data, labels, test_size=0.2, random_state=42
        ) #TEST SIZE 0.3

# %%
# Define Neural Network
model = tf.keras.Sequential([
        tf.keras.layers.Dense(512, activation='relu', input_shape=(len(features),)),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(1)
    ])

# Optimizer 
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)  

# Compile the model
model.compile(optimizer=optimizer, loss='mean_squared_error')

model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_30 (Dense)            (None, 512)               6144
#
#  dense_31 (Dense)            (None, 512)               262656
#
#  dense_32 (Dense)            (None, 256)               131328
#
#  dense_33 (Dense)            (None, 128)               32896
#
#  dense_34 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 433,153
# Trainable params: 433,153
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
history = model.fit(train_data, train_target, epochs=100, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 1s 1s/step - loss: 24308.4434 - val_loss: 21714.8496
# Epoch 2/100
# 1/1 [==============================] - 0s 37ms/step - loss: 22486.3066 - val_loss: 20084.6758
# Epoch 3/100
# 1/1 [==============================] - 0s 40ms/step - loss: 20830.4629 - val_loss: 18203.2578
# Epoch 4/100
# 1/1 [==============================] - 0s 38ms/step - loss: 18917.4375 - val_loss: 16079.0811
# Epoch 5/100
# 1/1 [==============================] - 0s 44ms/step - loss: 16732.7598 - val_loss: 13714.3174
# Epoch 6/100
# 1/1 [==============================] - 0s 42ms/step - loss: 14279.4785 - val_loss: 11215.1582
# Epoch 7/100
# 1/1 [==============================] - 0s 42ms/step - loss: 11645.7500 - val_loss: 8831.9639
# Epoch 8/100
# 1/1 [==============================] - 0s 36ms/step - loss: 9054.4648 - val_loss: 7008.4297
# Epoch 9/100
# 1/1 [==============================] - 0s 38ms/step - loss: 6922.4697 - val_loss: 6343.4487
# Epoch 10/100
# 1/1 [==============================] - 0s 41ms/step - loss: 5817.5625 - val_loss: 7391.9033
# Epoch 11/100
# 1/1 [==============================] - 0s 42ms/step - loss: 6320.6079 - val_loss: 9401.5908
# Epoch 12/100
# 1/1 [==============================] - 0s 37ms/step - loss: 7871.6011 - val_loss: 10342.5547
# Epoch 13/100
# 1/1 [==============================] - 0s 38ms/step - loss: 8657.2451 - val_loss: 9714.3271
# Epoch 14/100
# 1/1 [==============================] - 0s 44ms/step - loss: 8147.1055 - val_loss: 8263.4238
# Epoch 15/100
# 1/1 [==============================] - 0s 41ms/step - loss: 6962.7798 - val_loss: 6796.5000
# Epoch 16/100
# 1/1 [==============================] - 0s 40ms/step - loss: 5806.1562 - val_loss: 5757.5610
# Epoch 17/100
# 1/1 [==============================] - 0s 40ms/step - loss: 5056.2251 - val_loss: 5215.8774
# Epoch 18/100
# 1/1 [==============================] - 0s 44ms/step - loss: 4752.8340 - val_loss: 5046.1187
# Epoch 19/100
# 1/1 [==============================] - 0s 40ms/step - loss: 4762.3906 - val_loss: 5056.2749
# Epoch 20/100
# 1/1 [==============================] - 0s 38ms/step - loss: 4897.0171 - val_loss: 5086.8877
# Epoch 21/100
# 1/1 [==============================] - 0s 39ms/step - loss: 5005.5059 - val_loss: 5039.3086
# Epoch 22/100
# 1/1 [==============================] - 0s 46ms/step - loss: 4997.9316 - val_loss: 4876.6416
# Epoch 23/100
# 1/1 [==============================] - 0s 39ms/step - loss: 4845.5454 - val_loss: 4603.5938
# Epoch 24/100
# 1/1 [==============================] - 0s 43ms/step - loss: 4559.1802 - val_loss: 4259.3115
# Epoch 25/100
# 1/1 [==============================] - 0s 41ms/step - loss: 4182.8257 - val_loss: 3902.4897
# Epoch 26/100
# 1/1 [==============================] - 0s 38ms/step - loss: 3780.7903 - val_loss: 3601.4727
# Epoch 27/100
# 1/1 [==============================] - 0s 37ms/step - loss: 3425.5295 - val_loss: 3416.3647
# Epoch 28/100
# 1/1 [==============================] - 0s 49ms/step - loss: 3183.6895 - val_loss: 3361.1707
# Epoch 29/100
# 1/1 [==============================] - 0s 39ms/step - loss: 3078.0320 - val_loss: 3385.2454
# Epoch 30/100
# 1/1 [==============================] - 0s 40ms/step - loss: 3070.0254 - val_loss: 3383.9624
# Epoch 31/100
# 1/1 [==============================] - 0s 38ms/step - loss: 3064.1523 - val_loss: 3267.0720
# Epoch 32/100
# 1/1 [==============================] - 0s 37ms/step - loss: 2970.5020 - val_loss: 3012.9871
# Epoch 33/100
# 1/1 [==============================] - 0s 47ms/step - loss: 2762.6257 - val_loss: 2677.5854
# Epoch 34/100
# 1/1 [==============================] - 0s 39ms/step - loss: 2485.7205 - val_loss: 2340.6929
# Epoch 35/100
# 1/1 [==============================] - 0s 40ms/step - loss: 2210.1965 - val_loss: 2066.1245
# Epoch 36/100
# 1/1 [==============================] - 0s 39ms/step - loss: 1991.4014 - val_loss: 1874.0543
# Epoch 37/100
# 1/1 [==============================] - 0s 42ms/step - loss: 1844.3201 - val_loss: 1740.8385
# Epoch 38/100
# 1/1 [==============================] - 0s 39ms/step - loss: 1745.7229 - val_loss: 1625.5426
# Epoch 39/100
# 1/1 [==============================] - 0s 38ms/step - loss: 1654.9458 - val_loss: 1493.6501
# Epoch 40/100
# 1/1 [==============================] - 0s 42ms/step - loss: 1539.2786 - val_loss: 1329.1919
# Epoch 41/100
# 1/1 [==============================] - 0s 42ms/step - loss: 1384.9718 - val_loss: 1138.0905
# Epoch 42/100
# 1/1 [==============================] - 0s 40ms/step - loss: 1201.2725 - val_loss: 941.4133
# Epoch 43/100
# 1/1 [==============================] - 0s 40ms/step - loss: 1012.5428 - val_loss: 766.7661
# Epoch 44/100
# 1/1 [==============================] - 0s 41ms/step - loss: 848.5233 - val_loss: 631.2401
# Epoch 45/100
# 1/1 [==============================] - 0s 45ms/step - loss: 726.8228 - val_loss: 528.4521
# Epoch 46/100
# 1/1 [==============================] - 0s 39ms/step - loss: 638.7390 - val_loss: 436.9103
# Epoch 47/100
# 1/1 [==============================] - 0s 39ms/step - loss: 558.7714 - val_loss: 336.2206
# Epoch 48/100
# 1/1 [==============================] - 0s 53ms/step - loss: 460.9062 - val_loss: 230.1523
# Epoch 49/100
# 1/1 [==============================] - 0s 40ms/step - loss: 345.6397 - val_loss: 142.2596
# Epoch 50/100
# 1/1 [==============================] - 0s 42ms/step - loss: 238.0930 - val_loss: 91.9244
# Epoch 51/100
# 1/1 [==============================] - 0s 41ms/step - loss: 162.2682 - val_loss: 76.4956
# Epoch 52/100
# 1/1 [==============================] - 0s 40ms/step - loss: 122.0765 - val_loss: 78.1946
# Epoch 53/100
# 1/1 [==============================] - 0s 44ms/step - loss: 102.2770 - val_loss: 79.2501
# Epoch 54/100
# 1/1 [==============================] - 0s 42ms/step - loss: 84.8248 - val_loss: 72.0060
# Epoch 55/100
# 1/1 [==============================] - 0s 40ms/step - loss: 62.5316 - val_loss: 64.6402
# Epoch 56/100
# 1/1 [==============================] - 0s 44ms/step - loss: 42.4838 - val_loss: 68.1535
# Epoch 57/100
# 1/1 [==============================] - 0s 37ms/step - loss: 36.1844 - val_loss: 88.6565
# Epoch 58/100
# 1/1 [==============================] - 0s 45ms/step - loss: 48.4426 - val_loss: 119.1836
# Epoch 59/100
# 1/1 [==============================] - 0s 56ms/step - loss: 70.2892 - val_loss: 145.6638
# Epoch 60/100
# 1/1 [==============================] - 0s 40ms/step - loss: 86.5479 - val_loss: 161.1145
# Epoch 61/100
# 1/1 [==============================] - 0s 55ms/step - loss: 90.2944 - val_loss: 168.6263
# Epoch 62/100
# 1/1 [==============================] - 0s 43ms/step - loss: 86.8100 - val_loss: 173.8226
# Epoch 63/100
# 1/1 [==============================] - 0s 44ms/step - loss: 84.9784 - val_loss: 178.7160
# Epoch 64/100
# 1/1 [==============================] - 0s 39ms/step - loss: 87.8160 - val_loss: 178.6640
# Epoch 65/100
# 1/1 [==============================] - 0s 42ms/step - loss: 90.8859 - val_loss: 168.9736
# Epoch 66/100
# 1/1 [==============================] - 0s 42ms/step - loss: 87.8047 - val_loss: 149.2116
# Epoch 67/100
# 1/1 [==============================] - 0s 41ms/step - loss: 77.1464 - val_loss: 125.4234
# Epoch 68/100
# 1/1 [==============================] - 0s 57ms/step - loss: 63.5463 - val_loss: 103.6196
# Epoch 69/100
# 1/1 [==============================] - 0s 40ms/step - loss: 53.2079 - val_loss: 86.8720
# Epoch 70/100
# 1/1 [==============================] - 0s 44ms/step - loss: 48.4228 - val_loss: 73.5605
# Epoch 71/100
# 1/1 [==============================] - 0s 38ms/step - loss: 46.3196 - val_loss: 60.2304
# Epoch 72/100
# 1/1 [==============================] - 0s 56ms/step - loss: 42.5112 - val_loss: 46.2343
# Epoch 73/100
# 1/1 [==============================] - 0s 39ms/step - loss: 36.4718 - val_loss: 34.3091
# Epoch 74/100
# 1/1 [==============================] - 0s 38ms/step - loss: 31.3947 - val_loss: 26.6415
# Epoch 75/100
# 1/1 [==============================] - 0s 47ms/step - loss: 30.0585 - val_loss: 22.6639
# Epoch 76/100
# 1/1 [==============================] - 0s 39ms/step - loss: 32.0046 - val_loss: 19.8950
# Epoch 77/100
# 1/1 [==============================] - 0s 39ms/step - loss: 34.4076 - val_loss: 16.4613
# Epoch 78/100
# 1/1 [==============================] - 0s 44ms/step - loss: 35.0881 - val_loss: 12.5980
# Epoch 79/100
# 1/1 [==============================] - 0s 39ms/step - loss: 34.2768 - val_loss: 9.8177
# Epoch 80/100
# 1/1 [==============================] - 0s 40ms/step - loss: 33.5885 - val_loss: 9.0268
# Epoch 81/100
# 1/1 [==============================] - 0s 41ms/step - loss: 34.0526 - val_loss: 9.5205
# Epoch 82/100
# 1/1 [==============================] - 0s 55ms/step - loss: 35.0211 - val_loss: 9.8170
# Epoch 83/100
# 1/1 [==============================] - 0s 45ms/step - loss: 35.0683 - val_loss: 9.2595
# Epoch 84/100
# 1/1 [==============================] - 0s 39ms/step - loss: 33.5892 - val_loss: 8.4775
# Epoch 85/100
# 1/1 [==============================] - 0s 40ms/step - loss: 31.3504 - val_loss: 8.4966
# Epoch 86/100
# 1/1 [==============================] - 0s 41ms/step - loss: 29.5169 - val_loss: 9.5972
# Epoch 87/100
# 1/1 [==============================] - 0s 71ms/step - loss: 28.4801 - val_loss: 11.1986
# Epoch 88/100
# 1/1 [==============================] - 0s 85ms/step - loss: 27.6984 - val_loss: 12.6121
# Epoch 89/100
# 1/1 [==============================] - 0s 69ms/step - loss: 26.5421 - val_loss: 13.7228
# Epoch 90/100
# 1/1 [==============================] - 0s 56ms/step - loss: 25.0062 - val_loss: 14.9503
# Epoch 91/100
# 1/1 [==============================] - 0s 52ms/step - loss: 23.6561 - val_loss: 16.6617
# Epoch 92/100
# 1/1 [==============================] - 0s 54ms/step - loss: 22.9482 - val_loss: 18.7561
# Epoch 93/100
# 1/1 [==============================] - 0s 51ms/step - loss: 22.7920 - val_loss: 20.7847
# Epoch 94/100
# 1/1 [==============================] - 0s 54ms/step - loss: 22.6991 - val_loss: 22.4278
# Epoch 95/100
# 1/1 [==============================] - 0s 72ms/step - loss: 22.3395 - val_loss: 23.7586
# Epoch 96/100
# 1/1 [==============================] - 0s 55ms/step - loss: 21.8237 - val_loss: 25.0036
# Epoch 97/100
# 1/1 [==============================] - 0s 57ms/step - loss: 21.4637 - val_loss: 26.1925
# Epoch 98/100
# 1/1 [==============================] - 0s 58ms/step - loss: 21.3712 - val_loss: 27.0592
# Epoch 99/100
# 1/1 [==============================] - 0s 72ms/step - loss: 21.3483 - val_loss: 27.3009
# Epoch 100/100
# 1/1 [==============================] - 0s 55ms/step - loss: 21.1337 - val_loss: 26.9071

# %%
prediction = model.predict(test_data)
print(prediction)
# Out:
# 1/1 [==============================] - 0s 95ms/step
# [[102.31055 ]
#  [ 94.27586 ]
#  [103.325134]
#  [ 91.5689  ]
#  [176.18198 ]
#  [191.1629  ]
#  [100.52502 ]]

# %%
def plot_loss(history):
  plt.plot(history.history['loss'], label='loss')
  plt.plot(history.history['val_loss'], label='val_loss')
  plt.xlabel('Epoch')
  plt.ylabel('Error [CO2 EMISSION]')
  plt.legend()
  plt.grid(True)

# %%
plot_loss(history)

# %%
# Function to read car data from the CSV database
def read_car_data():
    car_data = {}
    with open('car_data_dummy.csv', 'r') as file:
        reader = csv.DictReader(file, delimiter=';')
        for row in reader:
            car_type = row['CAR TYPE']
            car_year = int(row['YEAR'])
            vehicle_class = row['VEHICLE CLASS']
            engine_size = float(row['ENGINE SIZE (L)'])
            cylinders = int(row['CYLINDERS'])
            transmission = row['TRANSMISSION']
            fuel_type = row['FUEL TYPE']
            fuel_consumption_city = float(row['FUEL CONSUMPTION CITY'])
            fuel_consumption_highway = float(row['FUEL CONSUMPTION HWY'])
            comb1 = float(row['COMB (L/100 km)'])
            comb2 = float(row['COMB (mpg)'])
            co2_emission = float(row['CO2 EMISSIONS'])
            if car_type not in car_data:
                car_data[car_type] = []
            car_data[car_type].append({
                    'car_year': car_year,
                    'vehicle_class': vehicle_class,
                    'engine_size' : engine_size,
                    'cylinders' : cylinders,
                    'transmission': transmission,
                    'fuel_type': fuel_type,
                    'fuel_consumption_city': fuel_consumption_city,
                    'fuel_consumption_highway': fuel_consumption_highway,
                    'comb1' : comb1,
                    'comb2' : comb2,
                    'co2_emission': co2_emission
            })
    return car_data

# %%
# Function to calculate carbon emissions
def calculate_carbon_emissions(car_type, car_year, mileage, car_data, emission):
    warnings.simplefilter(action='ignore', category=FutureWarning)
    
    if car_type in car_data:
        cars = car_data[car_type]
        for car in cars:
            if car['car_year'] == car_year:
                #co2_emission = car['co2_emission']
                #total_emissions = mileage * co2_emission
                total_emissions = mileage * emission
                return total_emissions
    return None

# %%
def display_warning(carbon_emission, max_limit):
    if carbon_emission is not None:
        if carbon_emission > max_limit:
            print("Warning: The carbon emissions of your car exceed the maximum limit.")
        else: 
            carbon_remainder = max_limit - carbon_emission
            print(f"Your daily carbon emission remaining: {carbon_remainder} gram")

# %%
def read_alternative_data(mileage):
  alternative_emission = {}
  with open('Alternatives.csv', 'r') as file:
        reader = csv.DictReader(file, delimiter=';')
        for row in reader:
            trans_type = row['Transportation']
            trans_emission = int(row['CO2 Emission (g/km)'])
            alternative_emission[trans_type] = trans_emission * int(mileage)
  return alternative_emission

# %%
# Function to recommend alternatives based on their emissions
def recommendation(alternative_emission, max_limit):
    # Sort the alternative emissions dictionary by emission values in ascending order
    sorted_alternatives = sorted(alternative_emission.items(), key=lambda x: x[1])

    # Initialize a list to store recommended alternatives
    recommended_alternatives = []

    # Iterate over the sorted alternatives and check if their emissions are within the maximum limit
    for alternative, emission in sorted_alternatives:
        if emission <= max_limit:
            recommended_alternatives.append(alternative)

    # Display the recommended alternatives
    if recommended_alternatives:
        print("\nYou have exceeded the maximum limit of carbon emissions.")
        print("\nHere are some alternative transportation options with lower CO2 emissions.")
        print("Recommended alternatives:")
        for alternative in recommended_alternatives:
            alternative_emission_str = str(alternative_emission[alternative])
            print("- " + alternative + " with total emission " + alternative_emission_str + " gram")
    else:
        print("No alternatives found within the maximum limit.")

# %%
# Use the trained model for prediction
def predict(car_data):
  prediction = model.predict(usercar)
  carbonpred = prediction[0][0]

  print(f"\nPredicted CO2 Emission: {carbonpred} g/km")

  # Calculate carbon emissions
  carbon_emission = calculate_carbon_emissions(car_type, car_year, mileage, car_data, carbonpred)
  if carbon_emission is not None:
      print(f"\nTotal carbon emissions: {carbon_emission} gram.")
    
  try:
      if carbon_emission is not None:
          max_limit = float(max_limit_input) if max_limit_input else None

          # Display a warning if emissions exceed the maximum limit
          display_warning(carbon_emission, max_limit)

          # Recommend alternatives based on their emissions
          if carbon_emission > max_limit:
              alternative_emission = read_alternative_data(mileage)
              recommendation(alternative_emission, max_limit)
      else:
          print("Error: No emissions data found for the provided vehicle information.")
  except ValueError:
        print("Error: Invalid input. Please enter numeric values for mileage, vehicle year, and maximum limit.")

# Main function
def main():
    # Read vehicle data from the CSV database
    car_data = read_car_data()

    # Run the ML model training and prediction
    predict(car_data)

# Run the main function
main()
# Out:
# 1/1 [==============================] - 0s 103ms/step
#
# Predicted CO2 Emission: 193.88111877441406 g/km
#
# Total carbon emissions: 193.88111877441406 gram.
# Warning: The carbon emissions of your car exceed the maximum limit.
#
# You have exceeded the maximum limit of carbon emissions.
#
# Here are some alternative transportation options with lower CO2 emissions.
# Recommended alternatives:
# - Train with total emission 41 gram
# - Electric vehicle with total emission 53 gram

# %%
# Accuracy
prediction = model.predict(usercar)
carbonpred = prediction[0][0]
error = (abs(carbonpred-real[0])/real[0])*100
accuracy = abs(error-100)
print('This model hits an accuracy of ' + str(accuracy) + '% (an error of ' + str(error) + '%)')
# Out:
# 1/1 [==============================] - 0s 29ms/step
# This model hits an accuracy of 99.54346177491499% (an error of 0.45653822508500647%)
